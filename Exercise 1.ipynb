# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Exercise 1:

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv("steps.csv",sep=";") 
df2= pd.read_csv("survey.csv")

# %%
df = pd.merge(df1, df2, on = 'id')
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# 3        NaN        NaN        NaN  ...        NaN        NaN         Lyon
# 4        NaN        NaN        NaN  ...        NaN        NaN  Montpellier
#
#    gender    age  hh_size  education          education_1  height  weight
# ...

# %%
df["weight"].value_counts()
# Out:
# 72.0     40
# 65.0     35
# 73.0     32
# 80.0     31
# 55.0     31
#          ..
# 101.0     1
# 20.0      1
# 700.0     1
# 37.0      1
# 6.0       1
# Name: weight, Length: 72, dtype: int64

# %%
def above(x):
    if (x>5):
        return float ("NaN")
    else: 
        return x
df["weight"]=df["weight"].apply

# %%
df['steps_mean'] = df.loc[:,"20-6-2013":"13-5-2014"].mean(axis=1, skipna = True).round(1)
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014         city  gender  \
# 0     9929.0    12879.0    10541.0  ...        NaN     Bordeaux    Male
# 1     4024.0     3926.0    14595.0  ...        NaN        Lille    Male
# 2     8185.0     9630.0     8983.0  ...        NaN  Montpellier    Male
# 3        NaN        NaN        NaN  ...        NaN         Lyon    Male
# 4        NaN        NaN        NaN  ...        NaN  Montpellier  Female
#
#      age  hh_size  education          education_1  height  \
# ...

# %%
sns.displot(data=df,x="steps_mean",kde=True)

# %%
df["steps_mean"].describe()
# Out:
# count       925.000000
# mean       7036.626703
# std        7396.879454
# min           4.000000
# 25%        4636.000000
# 50%        6245.000000
# 75%        8399.700000
# max      201722.600000
# Name: steps_mean, dtype: float64

# %% [markdown]
# De grafiek is left skewed. En wist niet hoe ik moest inzoomen. Maar overduidelijk is de 200000 stappen niet representatief voor dit onderzoek. Alles boven de 25000 is niet relevant omdat het maar 1x voorkwamen. Overduidelijk iets mis gegaan in mijn code.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1acaff97c807> in <module>
# ----> 1 sns.catplot(data=df, kind="bar", x="gender", y="age")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3777     p = _CategoricalPlotter()
#    3778     p.require_numeric = plotter_class.require_numeric
# ...
